# %% [markdown]
# <a href="https://colab.research.google.com/github/liv11114/11207011/blob/main/Untitled102.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [teach-visulization
# /viz2_0050_0056_plotly.ipynb](https://github.com/tewei0328/teach-visulization/blob/main/viz2_0050_0056_plotly.ipynb)
#
# [teach-visulization
# /viz7_plotly_filter_html.ipynb](https://github.com/tewei0328/teach-visulization/blob/main/viz7_plotly_filter_html.ipynb)
#
# [Tesla,Inc.(TSLA)](https://hk.finance.yahoo.com/quote/TSLA/history/)

# %%
import plotly as plo
import pandas as pd

# %%
tar=pd.read_csv("https://raw.githubusercontent.com/liv11114/11207011/main/TSLA.csv")
tar.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0  2022/8/15  301.786682  313.133331  301.230011  309.320007  309.320007
# 1  2022/8/16  311.666656  314.666656  302.883331  306.563324  306.563324
# 2  2022/8/17  303.396667  309.656677  300.033325  303.996674  303.996674
# 3  2022/8/18  306.000000  306.500000  301.853333  302.869995  302.869995
# 4  2022/8/19  299.000000  300.359985  292.500000  296.666656  296.666656
#
#      Volume
# 0  89359200
# 1  88136400
# 2  68766000
# 3  47500500
# 4  61395300

# %%
import plotly.graph_objects as go
line1=go.Scatter(x=tar['Date'],y=tar['Adj Close'],name='Adj Close')

# %%
fig=go.Figure(line1)
fig.show()
plo.offline.plot(fig, filename='tesla.html')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
tar.shape
# Out:
# (251, 7)

# %%
tar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251 entries, 0 to 250
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       251 non-null    datetime64[ns]
#  1   Open       251 non-null    float64
#  2   High       251 non-null    float64
#  3   Low        251 non-null    float64
#  4   Close      251 non-null    float64
#  5   Adj Close  251 non-null    float64
#  6   Volume     251 non-null    int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 13.9 KB

# %%
tar.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  251.000000  251.000000  251.000000  251.000000  251.000000
# mean   211.297211  215.793864  206.380398  211.155538  211.155538
# std     51.301598   51.661235   50.809599   51.156110   51.156110
# min    103.000000  111.750000  101.809998  108.099998  108.099998
# 25%    176.635002  182.419998  172.504998  178.474998  178.474998
# 50%    198.539993  203.000000  192.889999  197.580002  197.580002
# 75%    255.710007  261.154998  251.669998  256.695007  256.695007
# max    311.666656  314.666656  305.579987  309.320007  309.320007
#
#              Volume
# count  2.510000e+02
# mean   1.255088e+08
# std    4.876363e+07
# min    4.186470e+07
# 25%    9.032650e+07
# 50%    1.203321e+08
# 75%    1.599710e+08
# max    3.065906e+08

# %%
type(tar.Date)
# Out:
# pandas.core.series.Series

# %%
tar.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0  2022/8/15  301.786682  313.133331  301.230011  309.320007  309.320007
# 1  2022/8/16  311.666656  314.666656  302.883331  306.563324  306.563324
# 2  2022/8/17  303.396667  309.656677  300.033325  303.996674  303.996674
# 3  2022/8/18  306.000000  306.500000  301.853333  302.869995  302.869995
# 4  2022/8/19  299.000000  300.359985  292.500000  296.666656  296.666656
#
#      Volume
# 0  89359200
# 1  88136400
# 2  68766000
# 3  47500500
# 4  61395300

# %%
tar['Date']=pd.to_datetime(tar['Date'])

# %%
tar['Date']>pd.to_datetime('2023/1/5')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 246     True
# 247     True
# 248     True
# 249     True
# 250     True
# Name: Date, Length: 251, dtype: bool

# %%
tar1=tar[tar['Date']>pd.to_datetime('2023/1/5')]

# %%
tar1.head()
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 100 2023-01-06  103.000000  114.389999  101.809998  113.059998  113.059998
# 101 2023-01-09  118.959999  123.519997  117.110001  119.769997  119.769997
# 102 2023-01-10  121.070000  122.760002  114.919998  118.849998  118.849998
# 103 2023-01-11  122.089996  125.949997  120.510002  123.220001  123.220001
# 104 2023-01-12  122.559998  124.129997  117.000000  123.559998  123.559998
#
#         Volume
# 100  220911100
# 101  190284000
# 102  167642500
# 103  183810800
# 104  169400900

# %%
line1=go.Scatter(x=tar1['Date'],y=tar1['Adj Close'],name='Adj Close')
fig=go.Figure(line1)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plo.offline.plot(fig,filename='tesla.html')
# Out:
# 'tesla.html'
