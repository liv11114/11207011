# %% [markdown]
# <a href="https://colab.research.google.com/github/liv11114/11207011/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plo

# %%
x=[1,2,3,4,5]

# %%
y=[i*i for i in x]

# %%
y
# Out:
# [1, 4, 9, 16, 25]

# %%
plo.plot(x,y)

# %%
plo.plot(x)
