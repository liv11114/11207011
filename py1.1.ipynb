# %%
1+1
# Out:
# 2

# %% [markdown]
# # 1.list

# %%
import matplotlib.pyplot as plo

# %%
x=[1,3,5,7,9]

# %%
y=[i*i*i*100/i+42 for i in x]

# %%
y
# Out:
# [142.0, 942.0, 2542.0, 4942.0, 8142.0]

# %%
plo.plot(x,y)

# %% [markdown]
# # 2.numpy

# %%
import matplotlib.pyplot as plo

# %%
import numpy as np

# %%
x=np.arange(1,101)

# %%
y=x*x*100/10-55+42

# %%
y
# Out:
# array([-3.0000e+00,  2.7000e+01,  7.7000e+01,  1.4700e+02,  2.3700e+02,
#         3.4700e+02,  4.7700e+02,  6.2700e+02,  7.9700e+02,  9.8700e+02,
#         1.1970e+03,  1.4270e+03,  1.6770e+03,  1.9470e+03,  2.2370e+03,
#         2.5470e+03,  2.8770e+03,  3.2270e+03,  3.5970e+03,  3.9870e+03,
#         4.3970e+03,  4.8270e+03,  5.2770e+03,  5.7470e+03,  6.2370e+03,
#         6.7470e+03,  7.2770e+03,  7.8270e+03,  8.3970e+03,  8.9870e+03,
#         9.5970e+03,  1.0227e+04,  1.0877e+04,  1.1547e+04,  1.2237e+04,
#         1.2947e+04,  1.3677e+04,  1.4427e+04,  1.5197e+04,  1.5987e+04,
#         1.6797e+04,  1.7627e+04,  1.8477e+04,  1.9347e+04,  2.0237e+04,
#         2.1147e+04,  2.2077e+04,  2.3027e+04,  2.3997e+04,  2.4987e+04,
#         2.5997e+04,  2.7027e+04,  2.8077e+04,  2.9147e+04,  3.0237e+04,
#         3.1347e+04,  3.2477e+04,  3.3627e+04,  3.4797e+04,  3.5987e+04,
#         3.7197e+04,  3.8427e+04,  3.9677e+04,  4.0947e+04,  4.2237e+04,
#         4.3547e+04,  4.4877e+04,  4.6227e+04,  4.7597e+04,  4.8987e+04,
#         5.0397e+04,  5.1827e+04,  5.3277e+04,  5.4747e+04,  5.6237e+04,
#         5.7747e+04,  5.9277e+04,  6.0827e+04,  6.2397e+04,  6.3987e+04,
#         6.5597e+04,  6.7227e+04,  6.8877e+04,  7.0547e+04,  7.2237e+04,
#         7.3947e+04,  7.5677e+04,  7.7427e+04,  7.9197e+04,  8.0987e+04,
#         8.2797e+04,  8.4627e+04,  8.6477e+04,  8.8347e+04,  9.0237e+04,
#         9.2147e+04,  9.4077e+04,  9.6027e+04,  9.7997e+04,  9.9987e+04])

# %%
plo.plot(x,y)

# %% [markdown]
# # 3.pandas

# %%
import matplotlib.pyplot as plo

# %%
import pandas as pd

# %%
import numpy as np

# %%
x=np.arange(1,11)

# %%
y=x*100/100*x-50+42

# %%
y
# Out:
# array([-7., -4.,  1.,  8., 17., 28., 41., 56., 73., 92.])

# %%
s=pd.DataFrame(x,y)

# %%
plo.plot(x,y)
