# %%
1+1
# Out:
# 2

# %% [markdown]
# # 1.list
# ### 使用Matplotlib繪製圖表：https://ithelp.ithome.com.tw/m/articles/10275865

# %%
import matplotlib.pyplot as plo

# %%
x=[1,3,5,7,9]

# %%
y=[i*i for i in x]

# %%
y
# Out:
# [1, 9, 25, 49, 81]

# %%
plo.plot(x,y)

# %% [markdown]
# # 2.numpy
# ### NumPy Matplotlib：https://www.runoob.com/numpy/numpy-matplotlib.html

# %%
import numpy as np 
from matplotlib import pyplot as plt

# %%
x = np.arange(1,11)

# %%
y =  x*x*3 +  10

# %%
plt.title("Matplotlib demo") 
plt.xlabel("x axis caption") 
plt.ylabel("y axis caption") 
plt.plot(x,y)

# %% [markdown]
# # pandas
# ### Python 中的歷史股價數據：
# ### https://towardsdatascience.com/historical-stock-price-data-in-python-a0b6dc826836

# %%
import pandas as pd
tickers_list = ['AAPL', 'WMT', 'IBM', 'MU', 'BA', 'AXP']

# %%
import yfinance as yf
data = yf.download(tickers_list,'2015-1-1')['Adj Close']
# Out:
# [*********************100%***********************]  6 of 6 completed

# %%
print(data.head())
# Out:
#                  AAPL        AXP          BA         IBM         MU        WMT
# Date
# 2015-01-02  24.531763  81.617996  113.657219  106.693787  34.264709  71.685661
# 2015-01-05  23.840664  79.459541  112.870033  105.014961  33.308254  71.477020
# 2015-01-06  23.842911  77.766121  111.540619  102.750206  32.410961  72.027817
# 2015-01-07  24.177240  79.464546  113.272362  102.078674  31.651712  73.938873
# 2015-01-08  25.106184  80.590973  115.275284  104.297356  33.199795  75.499443

# %%
import pandas as pd
tickers_list = ['AAPL', 'WMT', 'IBM', 'MU', 'BA', 'AXP']

# %%
import yfinance as yf
data = yf.download(tickers_list,'2015-1-1')['Adj Close']
# Out:
# [*********************100%***********************]  6 of 6 completed

# %%
print(data.head())
# Out:
#                  AAPL        AXP          BA         IBM         MU        WMT
# Date
# 2015-01-02  24.531765  81.617996  113.657211  106.693756  34.264709  71.685661
# 2015-01-05  23.840668  79.459549  112.870071  105.014984  33.308254  71.477036
# 2015-01-06  23.842911  77.766106  111.540619  102.750198  32.410961  72.027824
# 2015-01-07  24.177242  79.464539  113.272377  102.078728  31.651716  73.938873
# 2015-01-08  25.106186  80.590950  115.275269  104.297356  33.199787  75.499435

# %%
import matplotlib.pyplot as plt
((data.pct_change()+1).cumprod()).plot(figsize=(10, 7))

plt.legend()

plt.title("Returns", fontsize=16)

plt.ylabel('Cumulative Returns', fontsize=15)
plt.xlabel('Year', fontsize=10)

plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
import numpy as np

# %%
x=np.arange(1,11)

# %%
y=x*x*100-100

# %%
s=pd.DataFrame(x,y)

# %%
plt.plot(s)

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
x=[1,3,5,7,9]

# %%
y=[i*i*i for i in x]

# %%
s=pd.DataFrame(x,y)

# %%
plo.plot(s)
